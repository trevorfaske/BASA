# %%
library(data.table)
library(ggplot2)
library(ggsci)
library(viridis)
library(devtools)
library(readr)
library(plyr)
# Out:
# Loading required package: viridisLite
#
# Loading required package: usethis

# %%
source('~/g/src/R/Imports.R')

# %%
setwd('~/g/balsam')

# %% [markdown]
# # Make Pop_ID file
#     also add ploidy

# %%
indv<-read.table("filtering/good_snps.recode.vcf.012.indv",sep="\t")

# %%
unlist(strsplit(as.character(indv$V1[1]),"/"))
# Out:
# [1] "BS_AN_10"

# %%
indv$V1[1]
# Out:
# [1] BS_AN_10
# 335 Levels: BS_AN_1 BS_AN_10 BS_AN_11 BS_AN_12 BS_AN_2 BS_AN_3 ... BS_WC_9

# %%
Pop <- rep(NA,times=nrow(indv))
ID <- rep(NA,times=nrow(indv))
for (i in 1:nrow(indv)){
  Pop[i] <- unlist(strsplit(as.character(indv$V1[i]),"_"))[2]
  ID[i] <- unlist(strsplit(as.character(indv$V1[i]),"_"))[3] 
}
Pop_ID <- data.frame(Pop=Pop,ID=ID,All=indv$V1)
head(Pop_ID)
# Out:
#   Pop ID All
# 1 AN  10 BS_AN_10
# 2 AN  11 BS_AN_11
# 3 AN  12 BS_AN_12
# 4 AN  1  BS_AN_1
# 5 AN  2  BS_AN_2
# 6 AN  3  BS_AN_3

# %%
write.csv(Pop_ID,"Pop_ID.csv",row.names = FALSE)

# %% [markdown]
# # Make PCA

# %%
df012<-fread("filtering/good_snps.recode.vcf.012",sep="\t", data.table=F) 
df012 <- df012[,-1]

Pop_ID <- read.csv('Pop_ID.csv')

# %%
pca_out <- PCA_gen(df012,Pop_ID)
pve <- pca_out$pve[1:5]
# Out:
#     PC1     PC2     PC3     PC4     PC5
# 0.04430 0.02444 0.02055 0.01515 0.01502
# plot without title

# %%
pca_df <- pca_out$pca_df

# %%
pca_df <- merge(pca_df,Pop_ID,sort=FALSE)
head(pca_df)
# Out:
#   Pop ID All      Cvalue Bryce_ploid T_ploid PC1       PC2      PC3
# 1 AH   5 CD_AH_05 NA     NA          NA      -25.80995 3.227235 -29.75477
# 2 AH   6 CD_AH_06 NA     NA          NA      -36.90002 2.530629 -43.27000
# 3 AH   8 CD_AH_08 NA     NA          NA      -35.07012 4.416174 -41.80079
# 4 AH   9 CD_AH_09 NA     NA          NA      -32.62943 3.122053 -39.25267
# 5 AH  10 CD_AH_10 NA     NA          NA      -32.19858 2.769088 -39.16772
# 6 AH  11 CD_AH_11 NA     NA          NA      -37.65349 4.405914 -46.02603
#   PC4      PC5
# 1 4.877179 -1.3729019
# 2 7.998318 -0.9656638
# 3 7.490128 -1.9883744
# 4 7.066839 -1.6602232
# 5 6.908903  0.3898746
# 6 8.158015 -0.1943939

# %%
write.csv(pca_df,'pca_df.csv',row.names = FALSE)

# %% [markdown]
# # Plot by Population

# %%
pca_df <- read.csv('pca_df.csv')
pve <- c(0.04075, 0.03340)

# %%
ggplot(data = pca_df, aes(x=PC1,y=PC2,fill=as.character(Pop))) + 
  geom_point(pch=21,colour='black',size = 3)+ ggtitle("PCA ddocent base") +
  xlab(paste("PC",1," (",pve[1]*100,"%)",sep="")) + ylab(paste("PC",2," (",pve[2]*100,"%)",sep=""))  +
  #scale_fill_npg(name='Species:') + 
  #scale_fill_d3(name='Pop',palette = 'category20') + 
  theme_bw() + 
  theme(#legend.position = 'none',
    axis.text = element_text(size=11), 
    axis.title = element_text(size = 13, colour="black",face = "bold",vjust = 1),
    panel.border = element_rect(size = 1.5, colour = "black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank())
# Out:
# plot without title

# %% [markdown]
# # Plot by ploidy

# %%
### Bryce guess
ggplot(data = pca_df, aes(x=PC1,y=PC2,fill=as.character(Bryce_ploid))) + 
  geom_point(pch=21,colour='black',size = 3)+ ggtitle("PCA ddocent ploidy") +
  xlab(paste("PC",1," (",pve[1]*100,"%)",sep="")) + ylab(paste("PC",2," (",pve[2]*100,"%)",sep=""))  +
  scale_fill_npg(name='Ploidy:') + 
  #scale_fill_d3(name='Pop',palette = 'category20') + 
  theme_bw() + 
  theme(#legend.position = 'none',
    axis.text = element_text(size=11), 
    axis.title = element_text(size = 13, colour="black",face = "bold",vjust = 1),
    panel.border = element_rect(size = 1.5, colour = "black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank())
# Out:
# plot without title

# %%
### Trevor guess
ggplot(data = pca_df, aes(x=PC1,y=PC2,fill=as.character(T_ploid))) + 
  geom_point(pch=21,colour='black',size = 3)+ ggtitle("PCA ddocent ploidy") +
  xlab(paste("PC",1," (",pve[1]*100,"%)",sep="")) + ylab(paste("PC",2," (",pve[2]*100,"%)",sep=""))  +
  scale_fill_npg(name='Ploidy:') + 
  #scale_fill_d3(name='Pop',palette = 'category20') + 
  theme_bw() + 
  theme(#legend.position = 'none',
    axis.text = element_text(size=11), 
    axis.title = element_text(size = 13, colour="black",face = "bold",vjust = 1),
    panel.border = element_rect(size = 1.5, colour = "black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank())
# Out:
# plot without title
